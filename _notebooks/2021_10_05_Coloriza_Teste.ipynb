# %% [markdown]
# <a href="https://colab.research.google.com/github/aleilha/colorizando-fotos/blob/master/_notebooks/2021_10_05_Coloriza_Teste.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Fotografia: Miliciano Leal no Momento da Morte
# > "Imagem clicada pelo fotógrafo Robert Capa em ensaio feito durante a guerra civil espanhola"
#
# - toc: false
# - branch: master
# - badges: true
# - comments: false
# - categories: [War, Capa, Robert]
# - hide: false
# - author: Alexandre Ilha

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2021-11-03 00:40:17--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py.1’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2021-11-03 00:40:18 (53.6 MB/s) - ‘deoldify_wrapper.py.1’ saved [2623/2623]

# %% [markdown]
# Essa rede neural colore fotos

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# ...

# %% [markdown]
# ### Colorização de fotografia realizada por Robert Capa durante a guerra civil espanhola utilizando RedeNeural Deoldify

# %%
url='https://birdinflight.imgix.net/wp-content/uploads/2014/10/capa_cover.jpg?fm=pjpg&q=70&fit=crop&crop=faces'

# %%
#hide_input
deo.colorize(url, render_factor=10)
