# %% [markdown]
# # "Rua do Principe em Joinville meados de 1900"
# > "A cidade de Joinville foi fundada em 09 de março de 1851 por alemães e suiços, quando aqui aportaram as margens do Rio Cachoeira com a lagoa do Saguaçu. Primeiros imigrantes moravam no casarão dos Imigrantes, construído pela colonizadora de Hamburgo para moradia de um curto periodo de tempo, até que estes pudessem construir sua própria casa de madeira na região central da Cidade."
#
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - author: Rafael Beber
# - categories: [city, south america]

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-10-08 22:39:48--  https://raw.githubusercontent.com/awarischool/data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2614 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py.1’
#
# deoldify_wrapper.py 100%[===================>]   2.55K  --.-KB/s    in 0s
#
# 2020-10-08 22:39:48 (46.8 MB/s) - ‘deoldify_wrapper.py.1’ saved [2614/2614]

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Done!

# %% [markdown]
# - Fonte da Imagem: [/r/CortinaDoPassado](https://cortinadopassado.com.br/2019/05/15/fotos-antigas-joinville-1900-a-1920/)

# %%
#hide_input
deo.colorize('https://hinsching.files.wordpress.com/2019/05/joinville1.jpg')
