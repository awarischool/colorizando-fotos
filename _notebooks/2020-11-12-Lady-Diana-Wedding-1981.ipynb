# %% [markdown]
# <a href="https://colab.research.google.com/github/bruna-vb/colorizando-fotos/blob/master/_notebooks/2020-11-12-Lady-Diana-Wedding-1981.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Geting ready for The Crown
# > The next season of the serie is going to present the Lady Diana's arco, and the "fairytale wedding of the century", in the 80's.
# > An in preparation for series,  here we colorize this photo of the royal wedding using a neural network.
# > Are you also getting ready for The Crown? Tell us what you're watching in the comments!
#
# - author: Bruna Vogt B.
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [colorizing, royal wedding, season 4]

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-11-12 14:09:07--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-11-12 14:09:07 (42.8 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
from deoldify_wrapper import DeOldify
# Out:
#   Importing Libraries
# No module named 'deoldify'
# DeOldify not found, installing..
#   Cloning DeOldify Repository...
#   Opening DeOldify Folder
#   Importing Libraries
# /content/deoldify_wrapper.py:36: UserWarning: WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings
#   warnings.warn('WARNING: GPU not available. Activate it on Colab at Edit > Notebook Settings')
#   Installing Colab requirements...
#   Importing DeOldify Visualize module and FastAI
# ...

# %%
#hide
foto = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Downloading: "https://download.pytorch.org/models/resnet101-5d3b4d8f.pth" to /root/.cache/torch/hub/checkpoints/resnet101-5d3b4d8f.pth
# ...
# Done!

# %%
#hide_input
foto.colorize('https://encrypted-tbn0.gstatic.com/images?q=tbn%3AANd9GcSmHqf9SOMj2m01KLyUQhXFzhg8naOUBODp3g&usqp=CAU', render_factor=38, compare=True)

# %% [markdown]
# _Prince Charles and Diana's royal wedding, in July 29, from 1981_

# %% [markdown]
# ---

# %% [markdown]
# Image taken from the site: https://www.cosmopolitan.com/entertainment/celebs/g29438393/princess-diana-rare-wedding-photos/
