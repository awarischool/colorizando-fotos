# %% [markdown]
# <a href="https://colab.research.google.com/github/Fabriciome/colorizando-fotos/blob/master/_notebooks/2021-03-15-Colorindo_o_Mundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Colorindo o Mundo
# > Fotos colorizadas do Artista Sebastião Salgado
#
# - toc: false
# - branch: master
# - badges: false
# - comments: True
# - author: Fabrício Mello
# - categories: [paisagens, natureza, arte]

# %%
#hide
#Uso da biblioteca DeOldify_wrapper.py
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2021-03-16 22:52:06--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2021-03-16 22:52:06 (20.4 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
#Importa biblioteca DeOldify
from deoldify_wrapper import DeOldify

# %%
#hide
#Cria objeto com a biblioteca DeOldify
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.7/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# ...

# %%
#Caminho da Imagem na Internet
imagem1 = 'https://gazetadebarao.com.br/wp-content/uploads/2016/04/%C3%81rvores-Baob%C3%A1-cr%C3%A9d.-Sebasti%C3%A3o-Salgado.jpg'
imagem2 = 'https://casaclaudia.abril.com.br/wp-content/uploads/2016/11/51-salgado.jpeg?quality=95&strip=info&w=928'

# %% [markdown]
# #Foto 1

# %%
#hide_input
#Coloriza a imagem a partir da função colorized da biblioteca DeOldify
deo.colorize(imagem1)

# %% [markdown]
# #Foto 2

# %%
#hide_input
#Coloriza a imagem a partir da função colorized da biblioteca DeOldify
deo.colorize(imagem2)
