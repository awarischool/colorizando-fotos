# %% [markdown]
# <a href="https://colab.research.google.com/github/cassiasamp/colorizando-fotos/blob/master/_notebooks/2020-11-10-festa-casamento-1930.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # "Festa de casamento de 1930"
# > "Foto colorizada por redes neurais de uma noiva e três damas de honra."
#
# - author: Cássia Sampaio
# - toc: false
# - branch: master
# - badges: true
# - comments: true
# - categories: [casamento, noiva, festa]

# %% [markdown]
# - Fonte da imagem: [1930 Wedding Party](https://www.reddit.com/r/TheWayWeWere/comments/jreajn/1930s_wedding_party/)

# %%
#hide
# !wget https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Out:
# --2020-11-10 23:17:57--  https://raw.githubusercontent.com/awarischool/br-data-science/master/image-colorizer/deoldify_wrapper.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2623 (2.6K) [text/plain]
# Saving to: ‘deoldify_wrapper.py’
#
# deoldify_wrapper.py 100%[===================>]   2.56K  --.-KB/s    in 0s
#
# 2020-11-10 23:17:58 (48.5 MB/s) - ‘deoldify_wrapper.py’ saved [2623/2623]

# %%
#hide
from deoldify_wrapper import DeOldify

# %%
#hide
deo = DeOldify()
# Out:
#   Initializing Colorizer
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:442: UserWarning: Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.
#   warn("Your training set is empty. If this is by design, pass `ignore_empty=True` to remove this warning.")
# /usr/local/lib/python3.6/dist-packages/fastai/data_block.py:445: UserWarning: Your validation set is empty. If this is by design, use `split_none()`
#                  or pass `ignore_empty=True` when labelling to remove this warning.
#   or pass `ignore_empty=True` when labelling to remove this warning.""")
# Done!

# %%
#hide_input
deo.colorize('https://i.redd.it/q8x9q64rbcy51.jpg')

# %%
# link da imagem que o colorizador não conseguiu colorizar: https://fotografiamais.com.br/wp-content/uploads/2018/08/foto-preto-e-branco-fotografia-preto-e-branco-tecnicas.jpg

# %%
# deo.colorize('https://i.redd.it/q8x9q64rbcy51.jpg', render_factor=10, compare=False)

# %%
# deo.range_render_factor()
